# %%
import pandas as pd
pd.options.display.max_rows=200

# %%
df=pd.read_csv('../prec_results_demos.csv')
df.iloc[0]
# Out:
# prec_20                                                                                                    101.0
# COUNCIL AT LARGE-DEM_ALLAN DOMB                                                                         0.333333
# COUNCIL AT LARGE-DEM_BLONDELL REYNOLDS BROWN                                                             0.37037
# COUNCIL AT LARGE-DEM_CARLA M CAIN                                                                       0.135802
# COUNCIL AT LARGE-DEM_DEREK S GREEN                                                                      0.098765
# COUNCIL AT LARGE-DEM_ED NEILSON                                                                         0.345679
# COUNCIL AT LARGE-DEM_FRANK RIZZO                                                                        0.246914
# COUNCIL AT LARGE-DEM_HELEN GYM                                                                          0.666667
# ...

# %%
# !pip install pandas
