# %%
import pandas as pd
pd.options.display.max_rows=200
pd.options.display.max_columns=200

# %% [markdown]
# ## From README:
# Each row of the data represents one precinct.
# * The column `prec_20` is the unique precinct identifier. It concatenates the city ward and division numbers.
# * There are 122 columns of election results, structured as described above. The column names are of the format "OFFICE_CANDIDATENAME." The first of these is `COUNCIL AT LARGE-DEM_ALLAN DOMB` and the last is `LIEUTENANT GOVERNOR DEM - Write-in`.
# * Cluster ID values for each of three-, four-, five-, and six-cluster groupings (`clust_3`,`clust_4`,`clust_5`, and `clust_6`). These are  automatically generated numeric IDs, and they aren't consistent from grouping to grouping.
# * Precinct-level racial demographic data directly from the 2020 Census, in the columns `hisp`, `black`, `white`, `aapi`, and `other`. Shares of the total population are given as `hisp_share`, `black_share`, `white_share`, `aapi_share`, and `other_share`. This considers the adult (18+) population only (table P4 in the Census).
# * Raw precinct-level ACS demographics crosswalked on a population-weighted basis from census-tract-level data. These are the 6-digit fields that start with the letter "B." A dictionary denoting the value of these is [available from the Census Bureau](https://www.census.gov/programs-surveys/acs/technical-documentation/table-shells.html).
# * Calculated ACS demographics:
#     * `median_age` is the median age of all residents
#     * `mean_household` is the average number of residents per household
#     * `foreign_share` is the share of residents born outside the USA (USA includes Puerto Rico and other territories)
#     * `noneng_share` is the share of residents speaking a language other than English at home, irrespective of how well they speak English
#     * `edu_attain` is the share of residents having earned a Bachelor's degree or higher
#     * `mean_household_inc` is the average income of households
#     * `pov` is the poverty rate of individuals
#     * `mean_commute` is the average commute time for workers
#     * `two_parent` is the share of households with children that have two parents living at home
#     * `child_house` is the share of households where any number of children under 18 are resident
#     * `vet_share` is the share of adults who are veterans of the US military
#     * `vacancy` is the share of housing units in the precinct that are unoccupied
#     * `renter_rate` is the share of households who rent rather than own their homes

# %%
def load_precinct_data():
    df=pd.read_csv('../prec_results_demos.csv')
    df['prec_20'] = df['prec_20'].apply(lambda x: f'{int(x):04}')
    df['ward'] = df['prec_20'].apply(lambda x: x[:2])
    df['prec'] = df['prec_20'].apply(lambda x: x[2:])
    return df.set_index(['ward','prec']).sort_index()

# %%
df=load_precinct_data()
# df

# %%
vote_cols = [col for col in df.columns if col[0] == col[0].upper()]
qcols = [col for col in df.columns if col[0] != col[0].upper()]
# qcols

# %%
# vote_cols

# %%
import plotly.express as px
import plotly.io as pio
pio.templates.default = "none"

# %%
# px.scatter(
#     df,
#     x='white_share',
#     # y='mean_household_inc',
#     y='PRESIDENT OF THE UNITED STATES-DEM_BERNIE SANDERS',
#     height=800,
#     width=800,
#     color='largest_race',
# )

# %%
dfq = df.select_dtypes('number')
dfcorr = dfq.corr()

# %%
vcols=[c for c in dfcorr if c[0]==c[0].lower() and c.split('_')[0] not in {'clust','prec'} and c+'_share' not in set(dfcorr.columns)]
vdfcorr = dfcorr.loc[vcols]
vvdfcorr = dfcorr.loc[vcols][vcols]
vvdfcorr
# Out:
#                          vtd     total  hisp_share  white_share  black_share  \
# vacancy               -0.091799  -0.076603  1.000000     0.423720
# renter_rate           -0.243800  -0.270278  0.423720     1.000000
# largest_race_size     -0.161517   0.236639  0.206455    -0.139564
#
#                     largest_race_size
# vtd                         -0.266190
# total                       -0.298044
# hisp_share                  -0.346949
# white_share                 -0.123445
# black_share                  0.448172
# aapi_share                  -0.583686
# other_share                 -0.270700
# median_age                   0.001200
# mean_household               0.020427
# foreign_share               -0.479393
# noneng_share                -0.534487
# edu_attain                  -0.050691
# mean_household_inc          -0.043962
# pov                         -0.054338
# mean_commute                 0.059936
# two_parent                  -0.179757
# child_house                 -0.161517
# vet_share                    0.236639
# vacancy                      0.206455
# renter_rate                 -0.139564
# largest_race_size            1.000000

# %%
vdfcorr['PRESIDENT OF THE UNITED STATES-DEM_HILLARY CLINTON'].sort_values(ascending=False)
# Out:
# black_share           0.624353
# pov                   0.362866
# vacancy               0.320464
# largest_race_size     0.311027
# mean_commute          0.254514
# child_house           0.240631
# hisp_share            0.213689
# vet_share             0.111738
# renter_rate           0.048263
# median_age            0.007680
# mean_household        0.003304
# noneng_share         -0.001900
# vtd                  -0.109187
# other_share          -0.171924
# foreign_share        -0.193649
# aapi_share           -0.347302
# total                -0.347817
# mean_household_inc   -0.392415
# edu_attain           -0.448308
# two_parent           -0.500731
# white_share          -0.719399
# Name: PRESIDENT OF THE UNITED STATES-DEM_HILLARY CLINTON, dtype: float64

# %%
list(vdfcorr.columns)
# Out:
# ['COUNCIL AT LARGE-DEM_ALLAN DOMB',
#  'COUNCIL AT LARGE-DEM_BLONDELL REYNOLDS BROWN',
#  'COUNCIL AT LARGE-DEM_CARLA M CAIN',
#  'COUNCIL AT LARGE-DEM_DEREK S GREEN',
#  'COUNCIL AT LARGE-DEM_ED NEILSON',
#  'COUNCIL AT LARGE-DEM_FRANK RIZZO',
#  'COUNCIL AT LARGE-DEM_HELEN GYM',
#  'COUNCIL AT LARGE-DEM_ISAIAH THOMAS',
#  'COUNCIL AT LARGE-DEM_JENNE AYERS',
#  'COUNCIL AT LARGE-DEM_MARNIE AUMENT LOUGHREY',
#  'COUNCIL AT LARGE-DEM_PAUL STEINKE',
#  'COUNCIL AT LARGE-DEM_SHERRIE COHEN',
#  'COUNCIL AT LARGE-DEM_THOMAS WYATT',
#  'COUNCIL AT LARGE-DEM_W WILSON GOODE JR',
#  'COUNCIL AT LARGE-DEM_WILLIAM K GREENLEE',
#  'COUNCIL AT LARGE-DEM_WILSON ALEXANDER',
#  'COUNCIL AT LARGE-DEM_Write In ',
#  'JUSTICE OF THE SUPREME COURT-DEM_ANNE E LAZARUS',
#  'JUSTICE OF THE SUPREME COURT-DEM_CHRISTINE DONOHUE',
#  'JUSTICE OF THE SUPREME COURT-DEM_DAVID WECHT',
#  'JUSTICE OF THE SUPREME COURT-DEM_DWAYNE D WOODRUFF',
#  'JUSTICE OF THE SUPREME COURT-DEM_JOHN HENRY FORADORA',
#  'JUSTICE OF THE SUPREME COURT-DEM_KEVIN M DOUGHERTY',
#  'JUSTICE OF THE SUPREME COURT-DEM_Write In ',
#  'MAYOR-DEM_ANTHONY HARDY WILLIAMS_x',
#  'MAYOR-DEM_DOUG OLIVER',
#  'MAYOR-DEM_JIM KENNEY_x',
#  'MAYOR-DEM_LYNNE M ABRAHAM',
#  'MAYOR-DEM_NELSON DIAZ',
#  'MAYOR-DEM_T MILTON STREET SR',
#  'MAYOR-DEM_Write In ',
#  'ATTORNEY GENERAL-DEM_JOHN MORGANELLI',
#  'ATTORNEY GENERAL-DEM_JOSH SHAPIRO',
#  'ATTORNEY GENERAL-DEM_STEPHEN A ZAPPALA JR',
#  'ATTORNEY GENERAL-DEM_Write In',
#  'PRESIDENT OF THE UNITED STATES-DEM_BERNIE SANDERS',
#  'PRESIDENT OF THE UNITED STATES-DEM_HILLARY CLINTON',
#  'PRESIDENT OF THE UNITED STATES-DEM_ROQUE ROCKY DE LA FUENTE',
#  'PRESIDENT OF THE UNITED STATES-DEM_Write In',
#  'UNITED STATES SENATOR-DEM_JOE SESTAK',
#  'UNITED STATES SENATOR-DEM_JOHN FETTERMAN',
#  'UNITED STATES SENATOR-DEM_JOSEPH J VODVARKA',
#  'UNITED STATES SENATOR-DEM_KATIE MCGINTY',
#  'UNITED STATES SENATOR-DEM_Write In',
#  'CITY CONTROLLER-DEM_ALAN L BUTKOVITZ',
#  'CITY CONTROLLER-DEM_REBECCA RHYNHART',
#  'CITY CONTROLLER-DEM_Write In',
#  'DISTRICT ATTORNEY-DEM_JOE KHAN',
#  'DISTRICT ATTORNEY-DEM_JOHN O NEILL',
#  'DISTRICT ATTORNEY-DEM_LAWRENCE S KRASNER',
#  'DISTRICT ATTORNEY-DEM_MICHAEL W UNTERMEYER',
#  'DISTRICT ATTORNEY-DEM_RICH NEGRIN',
#  'DISTRICT ATTORNEY-DEM_TARIQ KARIM EL SHABAZZ',
#  'DISTRICT ATTORNEY-DEM_TERESA CARR DENI',
#  'DISTRICT ATTORNEY-DEM_Write In',
#  'LIEUTENANT GOVERNOR-DEM_JOHN FETTERMAN',
#  'LIEUTENANT GOVERNOR-DEM_KATHI COZZONE',
#  'LIEUTENANT GOVERNOR-DEM_MIKE STACK',
#  'LIEUTENANT GOVERNOR-DEM_NINA AHMAD',
#  'LIEUTENANT GOVERNOR-DEM_RAY SOSA',
#  'LIEUTENANT GOVERNOR-DEM_Write In',
#  'COUNCIL AT-LARGE-DEM_ADRIÁN RIVERA-REYES',
#  'COUNCIL AT-LARGE-DEM_ALLAN DOMB',
#  'COUNCIL AT-LARGE-DEM_ASA KHALIF',
#  'COUNCIL AT-LARGE-DEM_BETH FINN',
#  'COUNCIL AT-LARGE-DEM_BILLY THOMPSON',
#  'COUNCIL AT-LARGE-DEM_BOBBIE CURRY',
#  'COUNCIL AT-LARGE-DEM_DEJA LYNN ALVAREZ',
#  'COUNCIL AT-LARGE-DEM_DEREK S GREEN',
#  'COUNCIL AT-LARGE-DEM_DEVON CADE',
#  'COUNCIL AT-LARGE-DEM_EDWIN SANTANA',
#  'COUNCIL AT-LARGE-DEM_ERIKA ALMIRÓN',
#  'COUNCIL AT-LARGE-DEM_ERYN SANTAMOOR',
#  'COUNCIL AT-LARGE-DEM_ETHELIND BAYLOR',
#  'COUNCIL AT-LARGE-DEM_FAREED ABDULLAH',
#  'COUNCIL AT-LARGE-DEM_FERNANDO TREVIÑO',
#  'COUNCIL AT-LARGE-DEM_HELEN GYM',
#  'COUNCIL AT-LARGE-DEM_HENA VEIT',
#  'COUNCIL AT-LARGE-DEM_ISAIAH THOMAS',
#  'COUNCIL AT-LARGE-DEM_JOSEPH A DIORIO',
#  'COUNCIL AT-LARGE-DEM_JUSTIN DIBERARDINIS',
#  'COUNCIL AT-LARGE-DEM_KATHERINE GILMORE RICHARDSON',
#  'COUNCIL AT-LARGE-DEM_LATRICE Y BRYANT',
#  'COUNCIL AT-LARGE-DEM_MARK ROSS',
#  'COUNCIL AT-LARGE-DEM_OGBONNA PAUL HAGINS',
#  'COUNCIL AT-LARGE-DEM_SANDRA DUNGEE GLENN',
#  'COUNCIL AT-LARGE-DEM_VINNY BLACK',
#  'COUNCIL AT-LARGE-DEM_WAYNE ALLEN',
#  'COUNCIL AT-LARGE-DEM_WAYNE EDMUND DORSEY',
#  'COUNCIL AT-LARGE-DEM_Write In',
#  'MAYOR-DEM_ALAN BUTKOVITZ',
#  'MAYOR-DEM_ANTHONY HARDY WILLIAMS_y',
#  'MAYOR-DEM_JIM KENNEY_y',
#  'MAYOR-DEM_Write In',
#  'REGISTER OF WILLS-DEM_JACQUE P WHAUMBUSH',
#  'REGISTER OF WILLS-DEM_RONALD R DONATUCCI',
#  'REGISTER OF WILLS-DEM_TRACEY GORDON',
#  'REGISTER OF WILLS-DEM_Write In',
#  'SHERIFF-DEM_JEWELL WILLIAMS',
#  'SHERIFF-DEM_LARRY KING SR',
#  'SHERIFF-DEM_MALIKA RAHMAN',
#  'SHERIFF-DEM_ROCHELLE BILAL',
#  'SHERIFF-DEM_Write In',
#  'AUDITOR GENERAL-DEM_DEM_CHRISTINA M HARTMAN',
#  'AUDITOR GENERAL-DEM_DEM_H SCOTT CONKLIN',
#  'AUDITOR GENERAL-DEM_DEM_MICHAEL LAMB',
#  'AUDITOR GENERAL-DEM_DEM_NINA AHMAD',
#  'AUDITOR GENERAL-DEM_DEM_ROSE ROSIE MARIE DAVIS',
#  'AUDITOR GENERAL-DEM_DEM_TRACIE FOUNTAIN',
#  'AUDITOR GENERAL-DEM_DEM_Write In',
#  'DISTRICT ATTORNEY DEM CARLOS VEGA',
#  'DISTRICT ATTORNEY DEM LARRY KRASNER',
#  'DISTRICT ATTORNEY DEM Write-in',
#  'UNITED STATES SENATOR  DEM - ALEX KHALIL',
#  'UNITED STATES SENATOR  DEM - CONOR LAMB',
#  'UNITED STATES SENATOR  DEM - MALCOLM KENYATTA',
#  'UNITED STATES SENATOR  DEM - JOHN FETTERMAN',
#  'UNITED STATES SENATOR  DEM - Write-in',
#  'LIEUTENANT GOVERNOR  DEM - AUSTIN DAVIS',
#  'LIEUTENANT GOVERNOR  DEM - RAY SOSA',
#  'LIEUTENANT GOVERNOR  DEM - BRIAN SIMS',
#  'LIEUTENANT GOVERNOR  DEM - Write-in',
#  'clust_3',
#  'clust_4',
#  'clust_5',
#  'clust_6',
#  'vtd',
#  'prec_x',
#  'total',
#  'hisp',
#  'white',
#  'black',
#  'aapi',
#  'other',
#  'hisp_share',
#  'white_share',
#  'black_share',
#  'aapi_share',
#  'other_share',
#  'prec_y',
#  'B05012_001E',
#  'B05012_003E',
#  'B06007_001E',
#  'B06007_002E',
#  'B06009_001E',
#  'B06009_005E',
#  'B06009_006E',
#  'B19313_001E',
#  'B08201_001E',
#  'B06012_001E',
#  'B06012_002E',
#  'B08006_008E',
#  'B08006_014E',
#  'B08006_015E',
#  'B08006_001E',
#  'B08013_001E',
#  'B09005_002E',
#  'B09005_003E',
#  'B09005_001E',
#  'B99084_002E',
#  'B11005_002E',
#  'B11005_001E',
#  'B21001_002E',
#  'B21001_001E',
#  'B25002_003E',
#  'B25002_001E',
#  'B25003_001E',
#  'B25003_003E',
#  'median_age',
#  'mean_household',
#  'foreign_share',
#  'noneng_share',
#  'edu_attain',
#  'mean_household_inc',
#  'pov',
#  'mean_commute',
#  'two_parent',
#  'child_house',
#  'vet_share',
#  'vacancy',
#  'renter_rate',
#  'largest_race_size']

# %%
# dfcorr

# %%
dfq.clust()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/py/jyzw5nyj1fnf0c_1czgsg2fc0000gn/T/ipykernel_6225/3771889075.py in ?()
# ----> 1 dfq.clust()
#
# ~/github/philadata/.venv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'clust'

# %%
import plotly.figure_factory as ff
figdf = vvdfcorr
fig = ff.create_dendrogram(figdf, orientation='left', labels=figdf.index)
fig.update_layout(height=800, width=1600)
fig

# %%
# Out:
#                          vtd     total      hisp     white     black  \
# vtd                 1.000000  0.009116  0.043911 -0.006548 -0.045920
# total               0.009116  1.000000  0.215336  0.692643 -0.022485
# hisp                0.043911  0.215336  1.000000 -0.083919 -0.214224
# white              -0.006548  0.692643 -0.083919  1.000000 -0.579813
# black              -0.045920 -0.022485 -0.214224 -0.579813  1.000000
# aapi                0.084679  0.612681  0.111454  0.386989 -0.239568
# other               0.051398  0.648315 -0.013163  0.477584 -0.064247
# hisp_share          0.014658 -0.014971  0.934090 -0.203293 -0.260610
# white_share         0.058930  0.355213 -0.156412  0.881502 -0.740587
# black_share        -0.109014 -0.398994 -0.344523 -0.742165  0.871678
# aapi_share          0.176257  0.350688  0.089866  0.252418 -0.339343
# other_share         0.078070  0.056104 -0.194742  0.068965 -0.031649
# median_age         -0.012281 -0.026548  0.030450  0.003615 -0.047939
# mean_household     -0.051224 -0.201539 -0.080674 -0.038611 -0.179217
